# %%
import json
import urllib
import pandas as pd

raw_results = json.load(urllib.urlopen("https://www.kimonolabs.com/api/2cyn0cpm?apikey=kHZBd0fMHssuf7WQPVwLwc3NAT30lmPw"))

results = raw_results['results']['collection1']    

data = pd.DataFrame(results)

data.head()
# Out:
#            Availability  Bed Type        Beds     Guests  \
# 0  1 night minimum stay  Real Bed       1 Bed   3 Guests
# 1                   NaN  Real Bed       1 Bed   4 Guests
# 2                   NaN       NaN  5 Bedrooms  14 Guests
# 3  1 night minimum stay  Real Bed       1 Bed   3 Guests
# 4                   NaN       NaN  3 Bedrooms  10 Guests
#
#                                             Location                     Pets  \
# 0  {u'text': u'Minden, NV, United States', u'href...  Cat(s) and Other pet(s)
# 1  {u'text': u'South Lake Tahoe, CA, United State...                      NaN
# 2  {u'text': u'South Lake Tahoe, CA, United State...                      NaN
# 3  {u'text': u'Carson City, NV, United States', u...                      NaN
# 4  {u'text': u'South Lake Tahoe, CA, United State...                      NaN
#
#   Price                                      Property type      Rental Type  \
# ...
